# %% [markdown]
# <a href="https://colab.research.google.com/github/Nadezda-Sut/statistics_in_science/blob/main/R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# # Define the user library directory
# user_lib <- "/content/R-packages/"
#
# # Create the directory if it doesn't exist
# dir.create(user_lib, showWarnings = FALSE)
#
# # Set the user library directory as the primary library path
# .libPaths(c(user_lib, .libPaths()))
#
# # Install the required packages
# packages_to_install <- c("polycor", "psych", "factoextra")
# install.packages(packages_to_install)

# %%
#link google colab and google drive

from google.colab import drive
drive.mount('/content/gdrive')

# %%
import pandas as pd

# Specify the path to the Excel file in your Google Drive
file_path = "/content/gdrive/My Drive/Colab Notebooks/Mik.xlsx"

# Read the Excel file into a Pandas DataFrame
data = pd.read_excel(file_path)

# Now you can work with the 'data' DataFrame
print(data)
# Out:
#      Студенты (1)школьники(0)  Использую для учебных и образовательных целей  \
# 0                           1                                              3
# 1                           1                                              0
# 2                           1                                              0
# 3                           1                                              0
# 4                           1                                              0
# ..                        ...                                            ...
# 564                         0                                             10
# 565                         0                                              0
# 566                         0                                              2
# 567                         0                                              1
# 568                         0                                              0
#
# ...

# %%
# %%R -i data
# Out:
# NULL
# /usr/local/lib/python3.10/dist-packages/rpy2/robjects/pandas2ri.py:55: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for name, values in obj.iteritems():

# %%
# %%R
# # Load necessary libraries
# library(polycor)
# library(psych)
# library(factoextra)
#
# # Specify the variables you want to include in the factor analysis
# selected_variables <- c('Компонент знаний',
#  'Компонент ответственности (обеспечения безопасности) ',
#  'Компонент умений',
#  '1. Для развлечения, отдыха',
#  '2. Для общения',
#  '3. Для учебы',
#  '4. Для поиска информации, не связанной с учебой',
#  '5. Для покупок',
#  '1. Поиск готовых решений и ответов, выполненных заданий',
#  '2. Поиск дополнительной информации, которой нет в учебниках',
#  '4. Просмотр видеоуроков',
#  '5. Просмотр научно-популярных и художественных фильмов, которые нужны для учебы',
#  '6. Тесты и тренажеры для самопроверки, подготовки к экзаменам и контрольным работам',
#  '7. Моделирование экспериментов в виртуальной среде',
#  '8. Дополнительные занятия (например, по скайпу)',
#  '9. Участие в онлайн-олимпиадах и конкурсах',
#  '10. Обмен информацией, связанной с учебой, с одногруппниками (в мессенджерах, социальных сетях)',
#  '11. Обмен информацией, связанной с учебой, с преподавателями (в мессенджерах, социальных сетях)')
#
# # Create a new DataFrame with only the selected variables
# selected_data <- data[selected_variables]
#
# # Calculate polychoric correlations with custom parameters
# polychoric_matrix <- polychor(x = selected_data, ML = TRUE)
#
# # Factor analysis using the polychoric correlation matrix
# factor_analysis_result <- fa(polychoric_matrix, nfactors = 3, rotate = "varimax")
#
# # Print the factor loadings
# print("Factor Loadings:")
# print(factor_analysis_result$loadings)
#
# # Bartlett’s Test
# bartlett_test <- cortest.bartlett(polychoric_matrix)
# print("Bartlett’s Test:")
# print("Chi-Square Value:", bartlett_test$chisq)
# print("Degrees of Freedom:", bartlett_test$df)
# print("P-value:", bartlett_test$p.value)
#
# # Kaiser-Meyer-Olkin (KMO) Test
# kmo_result <- KMO(polychoric_matrix)
# print("\nKaiser-Meyer-Olkin (KMO) Test:")
# print("KMO Overall:", kmo_result$MSA)
# print("KMO Model:", kmo_result$MSA.ind)
#
# # Scree Plot
# screeplot(factor_analysis_result)
#
# # Principal Component Scores
# factor_scores <- as.data.frame(factor_analysis_result$scores)
# colnames(factor_scores) <- c('Factor 1', 'Factor 2', 'Factor 3')
# print("\nPrincipal Component Scores:")
# print(factor_scores)

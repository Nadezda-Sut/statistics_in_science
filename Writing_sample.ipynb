# %% [markdown]
# <a href="https://colab.research.google.com/github/Nadezda-Sut/statistics_in_science/blob/main/Writing_sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

# %%
#link google colab and google drive

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# path to file in google drive

file_path = "/content/gdrive/My Drive/Colab Notebooks/all_data_new.csv"
data = pd.read_csv(file_path)
data
# Out:
#      №  Возраст  Пол  Интернет ответ  Интернет время  Time-test: Среднее 1 1  \
# 0    2       13    1               1             291                   223.3
# 1    3       13    0               1             420                   291.8
# 2    6       16    0               1              58                   275.1
# 3    7       16    0               0              36                   341.4
# 4    8       15    0               1             228                   313.2
# 5    9       17    1               1             481                   309.1
# 6   10       11    0               0             395                   299.5
# 7   12       12    1               1             254                   315.2
# 8   13       13    1               1             119                   346.9
# 9   14       14    0               1             177                   275.7
# 10  16       14    0               0              56                   342.9
# ...

# %%
data.keys()
# Out:
# Index(['№', 'Возраст', 'Пол', 'Интернет ответ', 'Интернет время',
#        'Time-test: Среднее 1 1',
#        'Time-test: Среднее время реакции, серия 1 (Часть 2)',
#        'Time-test: Среднее время реакции, серия 2 (Часть 1)',
#        'Time-test: Среднее время реакции, серия 2 (Часть 2)',
#        'Time-test: Ош 2 1', 'Time-test: Количество ошибок, серия 2 (Часть 2) ',
#        'WMem: Количество объектов, серия 1',
#        'WMem: Количество объектов, серия 2',
#        'WMem: Количество объектов, серия 3',
#        'Время фиксации на области интереса (тексте)',
#        'Длительность первой фиксации на области интереса',
#        'Среднее время фиксации', 'Все фиксации'],
#       dtype='object')

# %%
fig,ax = plt.subplots(1,figsize=(60, 20))

ax = sns.boxplot(data=data)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45)

plt.show()

# %%
import pandas as pd

# Create an empty DataFrame to store the outliers
outliers_df = pd.DataFrame(columns=['Variable', 'Outlier Values'])

# Calculate and store the outliers for each variable
for column in data.columns:
    q1 = data[column].quantile(0.25)
    q3 = data[column].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)][column]
    if not outliers.empty:
        outliers_df = outliers_df.append({'Variable': column, 'Outlier Values': outliers.tolist()}, ignore_index=True)

# Display the table with outliers
print("Outliers Table:")
display(HTML(outliers_df.to_html()))
# Out:
# Outliers Table:
# <ipython-input-38-2443add9f9b2>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   outliers_df = outliers_df.append({'Variable': column, 'Outlier Values': outliers.tolist()}, ignore_index=True)
# <ipython-input-38-2443add9f9b2>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   outliers_df = outliers_df.append({'Variable': column, 'Outlier Values': outliers.tolist()}, ignore_index=True)
# <ipython-input-38-2443add9f9b2>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   outliers_df = outliers_df.append({'Variable': column, 'Outlier Values': outliers.tolist()}, ignore_index=True)
# ...

# %%
! pip install factor-analyzer

# %%
import pandas as pd
import matplotlib.pyplot as plt
from factor_analyzer import FactorAnalyzer
from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity, calculate_kmo
from IPython.display import display, HTML

# Assume you have loaded your data into the 'data' DataFrame


# Specify the variables you want to include in the factor analysis
selected_variables = ['Возраст',
    'Пол',
    'Интернет ответ',
    'Интернет время',
    #'Time-test: Среднее 1 1',
    #'Time-test: Среднее время реакции, серия 1 (Часть 2)',
    'Time-test: Среднее время реакции, серия 2 (Часть 1)',
    'Time-test: Среднее время реакции, серия 2 (Часть 2)',
    'Time-test: Ош 2 1',
    'Time-test: Количество ошибок, серия 2 (Часть 2) ',
    'WMem: Количество объектов, серия 1',
    'WMem: Количество объектов, серия 2',
    'WMem: Количество объектов, серия 3',
    'Время фиксации на области интереса (тексте)',
    'Длительность первой фиксации на области интереса',
    #'Все фиксации'
    ]  # Replace with the actual variable names you want to include

# Assuming you have already conducted the factor analysis and have factor loadings
# Let's say you want to combine variables into Factor 1


selected_data = data[selected_variables]
# Create a new DataFrame with only the selected variables
#selected_data = data[selected_variables]

# Specify the number of factors you want to extract
num_factors = 3

# Calculate the cumulative variance explained by factors
cumulative_variance_explained = []
for i in range(1, len(selected_variables) + 1):
    factor_analyzer = FactorAnalyzer(rotation='geomin_obl', n_factors=i, method='uls')
    factor_analyzer.fit(selected_data)
    fa_var = factor_analyzer.get_factor_variance()
    total_cum_variance = fa_var[-1][-1]  # Access the last element of the array
    cumulative_variance_explained.append(total_cum_variance)

#'varimax', 'oblimax', 'quartimax', 'equamax', 'geomin_ort', 'oblimin', 'quartimin', 'geomin_obl', None


# Print the cumulative variance explained by factors
for i, variance_explained in enumerate(cumulative_variance_explained):
    print(f"Total {variance_explained * 100:.2f}% Cumulative Variance explained by the {i + 1} factors")

# Initialize the factor analyzer with the desired number of factors
factor_analyzer = FactorAnalyzer(n_factors=num_factors, rotation='geomin_obl', method='uls')

# Fit the model to your selected data
factor_analyzer.fit(selected_data)

# Get the factor loadings
factor_loadings = factor_analyzer.loadings_

# Create a pandas DataFrame from the factor loadings
factor_loading_df = pd.DataFrame(factor_loadings, columns=[f'Factor {i+1}' for i in range(num_factors)], index=selected_data.columns)

# Print the factor loadings table with grid lines using HTML
print("Factor Loadings Table:")
display(HTML(factor_loading_df.to_html()))

# Bartlett’s Test
chi_square_value, p_value = calculate_bartlett_sphericity(selected_data)
print("Bartlett’s Test:")
print("Chi-Square Value:", chi_square_value)
print("P-value:", p_value)

# Kaiser-Meyer-Olkin (KMO) Test
kmo_all, kmo_model = calculate_kmo(selected_data)
print("\nKaiser-Meyer-Olkin (KMO) Test:")
print("KMO Overall:", kmo_all)
print("KMO Model:", kmo_model)

# Scree Plot
ev, v = factor_analyzer.get_eigenvalues()
plt.plot(range(1, len(ev) + 1), ev, marker='o')
plt.title('Scree Plot')
plt.xlabel('Factor')
plt.ylabel('Eigenvalue')
plt.show()


# Calculate basic descriptive statistics for the selected data
descriptive_stats = selected_data.describe()

# Calculate skewness for each variable
skewness = selected_data.skew()

# Calculate kurtosis for each variable
kurtosis_value = selected_data.kurtosis()

# Add skewness and kurtosis to the descriptive statistics DataFrame
descriptive_stats.loc['Skewness'] = skewness
descriptive_stats.loc['Kurtosis'] = kurtosis_value

# Print the descriptive statistics
print("Descriptive Statistics:")
display(HTML(descriptive_stats.to_html()))

# Get the factor scores
factor_scores = factor_analyzer.transform(selected_data)

# Calculate the correlation matrix among factor scores
factor_scores_corr_matrix = pd.DataFrame(factor_scores).corr()

# Print the factor correlation matrix
print("Factor Correlation Matrix:")
display(HTML(factor_scores_corr_matrix.to_html()))

# Get the communalities (h^2)
communalities = factor_analyzer.get_communalities()

# Create a pandas DataFrame for communalities
communalities_df = pd.DataFrame(communalities, columns=['Communalities'], index=selected_data.columns)

# Print the communalities
print("Communalities:")
display(HTML(communalities_df.to_html()))
# Out:
# /usr/local/lib/python3.10/dist-packages/factor_analyzer/factor_analyzer.py:663: UserWarning: No rotation will be performed when the number of factors equals 1.
#   warnings.warn(
# Total 16.09% Cumulative Variance explained by the 1 factors
# Total 27.86% Cumulative Variance explained by the 2 factors
# Total 36.68% Cumulative Variance explained by the 3 factors
# Total 44.05% Cumulative Variance explained by the 4 factors
# Total 49.81% Cumulative Variance explained by the 5 factors
# Total 57.41% Cumulative Variance explained by the 6 factors
# Total 63.70% Cumulative Variance explained by the 7 factors
# Total 69.97% Cumulative Variance explained by the 8 factors
# Total 72.88% Cumulative Variance explained by the 9 factors
# Total 63.66% Cumulative Variance explained by the 10 factors
# Total 70.69% Cumulative Variance explained by the 11 factors
# Total 71.53% Cumulative Variance explained by the 12 factors
# Total 71.34% Cumulative Variance explained by the 13 factors
# ...

# %%
# Calculate the correlation matrix
correlation_matrix = selected_data.corr()

# Print the correlation matrix
print("\nCorrelation Matrix:")
display(HTML(correlation_matrix.to_html()))
# Out:
# Correlation Matrix:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Возраст</th>
#       <th>Пол</th>
#       <th>Интернет ответ</th>
#       <th>Интернет время</th>
#       <th>Time-test: Среднее время реакции, серия 2 (Часть 1)</th>
#       <th>Time-test: Среднее время реакции, серия 2 (Часть 2)</th>
#       <th>Time-test: Ош 2 1</th>
#       <th>Time-test: Количество ошибок, серия 2 (Часть 2)</th>
#       <th>WMem: Количество объектов, серия 1</th>
#       <th>WMem: Количество объектов, серия 2</th>
#       <th>WMem: Количество объектов, серия 3</th>
#       <th>Время фиксации на области интереса (тексте)</th>
#       <th>Длительность первой фиксации на области интереса</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Возраст</th>
#       <td>1.000000</td>
#       <td>0.036801</td>
#       <td>0.379902</td>
#       <td>-0.173711</td>
#       <td>-0.101543</td>
#       <td>-0.117933</td>
# ...

# %%
! pip install pingouin
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.6/198.6 kB 3.9 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for littleutils: filename=littleutils-0.2.2-py3-none-any.whl size=7028 sha256=d92866a757a5d7b9732c875c217811344d28b2db9776c8e4135c7285f357bf3c
#   Stored in directory: /root/.cache/pip/wheels/3d/fe/b0/27a9892da57472e538c7452a721a9cf463cc03cf7379889266
# Successfully built littleutils
# ...

# %%
import pingouin as pg


# Create a new DataFrame with only the selected variables
selected_data = data[selected_variables]

# Calculate Cronbach's alpha
alpha_result = pg.cronbach_alpha(selected_data)

# Extract the alpha value from the result (it's the first element in the tuple)
alpha_value = alpha_result[0]

# Print Cronbach's alpha
print(f'Cronbach\'s Alpha: {alpha_value:.2f}')
# Out:
# Cronbach's Alpha: -0.03

# %%
import statsmodels.api as sm

# %%
# binarize phone_1/comp_0 (the subject used a computer or telephone)
# binarization threshold

binthresh = np.mean(data['Интернет ответ'])

# 'binquality' column with Boolean type True or False

data['binquality'] = data['Интернет ответ'] > binthresh
data
# Out:
#      №  Возраст  Пол  Интернет ответ  Интернет время  Time-test: Среднее 1 1  \
# 0    2       13    1               1             291                   223.3
# 1    3       13    0               1             420                   291.8
# 2    6       16    0               1              58                   275.1
# 3    7       16    0               0              36                   341.4
# 4    8       15    0               1             228                   313.2
# 5    9       17    1               1             481                   309.1
# 6   10       11    0               0             395                   299.5
# 7   12       12    1               1             254                   315.2
# 8   13       13    1               1             119                   346.9
# 9   14       14    0               1             177                   275.7
# 10  16       14    0               0              56                   342.9
# ...

# %%
xcols = []


for key in data.keys():
  if key in [
      'Возраст',
      'Пол',
      #'Интернет время',
       #'Time-test: Среднее 1 1',
       #'Time-test: Среднее время реакции, серия 1 (Часть 2)',
       'Time-test: Среднее время реакции, серия 2 (Часть 1)',
       #'Time-test: Среднее время реакции, серия 2 (Часть 2)',
       'Time-test: Ош 2 1',
       'Time-test: Количество ошибок, серия 2 (Часть 2) ',
       'WMem: Количество объектов, серия 1',
       'WMem: Количество объектов, серия 2',
       'WMem: Количество объектов, серия 3',
       'Время фиксации на области интереса (тексте)',
       'Длительность первой фиксации на области интереса',
       #'Среднее время фиксации',
       'Все фиксации'
]:
                     xcols.append(key)

xcols
# Out:
# ['Возраст',
#  'Пол',
#  'Time-test: Среднее время реакции, серия 2 (Часть 1)',
#  'Time-test: Ош 2 1',
#  'Time-test: Количество ошибок, серия 2 (Часть 2) ',
#  'WMem: Количество объектов, серия 1',
#  'WMem: Количество объектов, серия 2',
#  'WMem: Количество объектов, серия 3',
#  'Время фиксации на области интереса (тексте)',
#  'Длительность первой фиксации на области интереса',
#  'Все фиксации']

# %%
# setup and run the logistic regression model
model = sm.Logit(data['binquality'],data[xcols])
results = model.fit(method='newton')

# have a look at the results!
results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.492683
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:             binquality   No. Observations:                   49
# Model:                          Logit   Df Residuals:                       38
# Method:                           MLE   Df Model:                           10
# Date:                Sat, 23 Sep 2023   Pseudo R-squ.:                  0.2838
# Time:                        14:28:55   Log-Likelihood:                -24.141
# converged:                       True   LL-Null:                       -33.709
# Covariance Type:            nonrobust   LLR p-value:                   0.03859
# ...
#                                                           coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
import statsmodels.api as sm

# Create a null model (no predictors)
null_model = sm.Logit(data['binquality'], [1] * len(data['binquality']))  # Use a constant as the only predictor

# Fit the null model
null_results = null_model.fit()

# Fit your logistic regression model
model = sm.Logit(data['binquality'], data[xcols])
results = model.fit()

# Calculate McFadden's Pseudo R-squared
null_log_likelihood = null_results.llf  # Log-likelihood of the null model
model_log_likelihood = results.llf  # Log-likelihood of the logistic regression model

mcfaddens_pseudo_r2 = 1 - (model_log_likelihood / null_log_likelihood)

print("McFadden's Pseudo R-squared:", mcfaddens_pseudo_r2)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.687932
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.492683
#          Iterations 7
# McFadden's Pseudo R-squared: 0.2838198198562607

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'data' contains your dataset
font_size = 15
axis_title_font = {'fontsize': 16}
plt.figure(figsize=(15, 6))

# First Plot
plt.subplot(1, 3, 1)
sns.violinplot(x=data['Интернет ответ'], y=data['Возраст'], palette="Set2")
#plt.title("Violin Plot of Knowledge Component")
plt.xlabel("False(0), Right(1)", fontdict=axis_title_font)
plt.ylabel("Age", fontdict=axis_title_font)
plt.xticks(fontsize=font_size)  # Set tick label font size
plt.yticks(fontsize=font_size)  # Set tick label font size

# Second Plot
plt.subplot(1, 3, 2)
sns.violinplot(x=data['Интернет ответ'], y=data['Пол'], palette="Set2")
#plt.title("Violin Plot of Security Responsibility Component")
plt.xlabel("False(0), Right(1)", fontdict=axis_title_font)
plt.ylabel("Sex", fontdict=axis_title_font)
plt.xticks(fontsize=font_size)  # Set tick label font size
plt.yticks(fontsize=font_size)  # Set tick label font size

# Third Plot
plt.subplot(1, 3, 3)
sns.violinplot(x=data['Интернет ответ'], y=data['Time-test: Среднее время реакции, серия 1 (Часть 2)'], palette="Set2")
#plt.title("Violin Plot of Skills Component")
plt.xlabel("False(0), Right(1)", fontdict=axis_title_font)
plt.ylabel("Average reaction time", fontdict=axis_title_font)
plt.xticks(fontsize=font_size)  # Set tick label font size
plt.yticks(fontsize=font_size)  # Set tick label font size


plt.tight_layout()
plt.show()

# %%
# Assuming 'data' contains your dataset
font_size = 15
axis_title_font = {'fontsize': 16}
plt.figure(figsize=(15, 6))

# Third Plot
plt.subplot(1, 3, 3)
sns.violinplot(x=data['Интернет ответ'], y=data['WMem: Количество объектов, серия 1'], palette="Set2")
#plt.title("Violin Plot of Skills Component")
plt.xlabel("False(0), Right(1)", fontdict=axis_title_font)
plt.ylabel("Average reaction time", fontdict=axis_title_font)
plt.xticks(fontsize=font_size)  # Set tick label font size
plt.yticks(fontsize=font_size)  # Set tick label font size


plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt



# Specify the variables you want to include in the pairplot
variables = ['WMem: Количество объектов, серия 1', 'Time-test: Ош 2 1', 'Интернет ответ']

# Rename the columns in the DataFrame to change variable names
data_renamed = data[variables].rename(columns={
    'WMem: Количество объектов, серия 1': 'Number of objects 1 (WM)',
    'Time-test: Ош 2 1': 'Number of errors 1 (no go)',
    'Интернет ответ': 'Internet Response'
})


# Create a pairplot with the custom variable names
sns.pairplot(data_renamed, kind='reg', hue='Internet Response')

# Show the pairplot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have your DataFrame 'data'

# Define variable names
internet_time = 'Time-test: Ош 2 1'
fixation_time = 'WMem: Количество объектов, серия 1'
internet_response = 'Интернет ответ'

# Specify the variables you want to include in the pairplot
variables = [internet_time, fixation_time, internet_response]

# Rename the columns in the DataFrame to change variable names
data_renamed = data[variables].rename(columns={
    internet_time: 'Number of errors 1 (no go)',
    fixation_time: 'Number of objects 1 (WM)',
    internet_response: 'Internet Response'
})

# Define a custom color palette (optional)
# custom_palette = sns.color_palette("viridis")

# Set the figure size
plt.figure(figsize=(20, 16))  # Adjust the size as needed

# Create a pairplot with the custom variable names and color palette
g = sns.pairplot(data_renamed, kind='reg', diag_kind="hist",hue='Internet Response',markers=["o", "s"])#palette=custom_palette)
# Customize the legend (optional)
g._legend.set_title('Response Types')  # Set a title for the legend

# Show the pairplot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have your DataFrame 'data'

# Define variable names
internet_time = 'Time-test: Количество ошибок, серия 2 (Часть 2) '
fixation_time = 'Возраст'
internet_response = 'Интернет ответ'

# Specify the variables you want to include in the pairplot
variables = [internet_time, fixation_time, internet_response]

# Rename the columns in the DataFrame to change variable names
data_renamed = data[variables].rename(columns={
    internet_time: 'Number of errors 2 (no go)',
    fixation_time: 'Age',
    internet_response: 'Internet Response'
})

# Define a custom color palette (optional)
# custom_palette = sns.color_palette("viridis")

# Set the figure size
plt.figure(figsize=(20, 16))  # Adjust the size as needed

# Create a pairplot with the custom variable names and color palette
g = sns.pairplot(data_renamed, kind='reg', diag_kind="hist",hue='Internet Response',markers=["o", "s"])#palette=custom_palette)
# Customize the legend (optional)
g._legend.set_title('Response Types')  # Set a title for the legend

# Show the pairplot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Your data and columns
cols2plot = ['Age', 'Number of errors 1 (no go)', 'Number of errors 2 (no go)',
             'Number of objects 1 (WM)', 'Answer to question (web search)']

# Rename specific columns in your DataFrame
data.rename(columns={
    'Возраст': 'Age',
    'Time-test: Ош 2 1': 'Number of errors 1 (no go)',
    'Time-test: Количество ошибок, серия 2 (Часть 2) ': 'Number of errors 2 (no go)',
    'WMem: Количество объектов, серия 1': 'Number of objects 1 (WM)',
    'Интернет ответ': 'Answer to question (web search)'
}, inplace=True)


# Create the pairplot
pair_plot = sns.pairplot(data[cols2plot], kind='reg', hue='Answer to question (web search)', diag_kind="hist")

# Show the plot
plt.show()

# %%
# Calculate the counts for 'Пол' (Gender) and 'Интернет ответ' (Internet Response)
gender_counts = data['Пол'].value_counts()
internet_response_counts = data['Интернет ответ'].value_counts()

# Labels for the pie chart
gender_labels = ['Male (Пол=1)', 'Female (Пол=0)']
internet_response_labels = ['Positive (Интернет ответ=1)', 'Negative/No (Интернет ответ=0)']

# Create a pie chart for Gender
plt.figure(figsize=(8, 4))
plt.pie(gender_counts, labels=gender_labels, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Gender')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# Create a pie chart for Internet Response
plt.figure(figsize=(8, 4))
plt.pie(internet_response_counts, labels=internet_response_labels, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Internet Response')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

selected_variables = [
    'Возраст',
    'Пол',
    'Интернет ответ',
    'Интернет время',
       #'Time-test: Среднее 1 1',
       #'Time-test: Среднее время реакции, серия 1 (Часть 2)',
       'Time-test: Среднее время реакции, серия 2 (Часть 1)',
       'Time-test: Среднее время реакции, серия 2 (Часть 2)',
       'Time-test: Ош 2 1',
       'Time-test: Количество ошибок, серия 2 (Часть 2) ',
       'WMem: Количество объектов, серия 1',
       'WMem: Количество объектов, серия 2',
       'WMem: Количество объектов, серия 3',
       'Время фиксации на области интереса (тексте)',
       'Длительность первой фиксации на области интереса',
       #'Все фиксации'
]  # Replace with the actual variable names you want to include

# Assuming you have already conducted the factor analysis and have factor loadings
# Let's say you want to combine variables into Factor 1


selected_data = data[selected_variables]

# Calculate the Spearman correlation matrix
correlation_matrix = selected_data.corr(method='spearman')

# Create a heatmap of the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.2)
plt.title("Spearman Correlation Heatmap")
plt.show()

# %%
selected_data.corr(method="spearman")
# Out:
#                                                      Возраст       Пол  \
# Возраст                                             1.000000  0.019020
# Пол                                                 0.019020  1.000000
# Интернет ответ                                      0.346442  0.273491
# Интернет время                                     -0.110878  0.240062
# Time-test: Среднее время реакции, серия 2 (Част... -0.102281  0.020242
# Time-test: Среднее время реакции, серия 2 (Част... -0.104396 -0.130121
# Time-test: Ош 2 1                                  -0.173236  0.156980
# Time-test: Количество ошибок, серия 2 (Часть 2)    -0.347601  0.088496
# WMem: Количество объектов, серия 1                 -0.270173 -0.278010
# WMem: Количество объектов, серия 2                 -0.112525  0.160885
# WMem: Количество объектов, серия 3                  0.031738  0.237777
# Время фиксации на области интереса (тексте)        -0.266720 -0.150362
# ...

# %%
from scipy.stats import spearmanr

# Assuming you want to calculate the correlation for variables 'Variable1' and 'Variable2'
variable1 = selected_data['Возраст']
variable2 = selected_data['Time-test: Количество ошибок, серия 2 (Часть 2) ']

# Calculate the Spearman correlation and p-value for the selected pair of variables
correlation, p_value = spearmanr(variable1, variable2)

# Print the result
print(f"Spearman Correlation: {correlation}")
print(f"P-Value: {p_value}")
# Out:
# Spearman Correlation: -0.3476008509728443
# P-Value: 0.014395572085859818

# %%
from scipy.stats import spearmanr

# Assuming you want to calculate the correlation for variables 'Variable1' and 'Variable2'
variable1 = selected_data['Возраст']
variable2 = selected_data['Интернет ответ']

# Calculate the Spearman correlation and p-value for the selected pair of variables
correlation, p_value = spearmanr(variable1, variable2)

# Print the result
print(f"Spearman Correlation: {correlation}")
print(f"P-Value: {p_value}")
# Out:
# Spearman Correlation: 0.34644225433933945
# P-Value: 0.014746945364937026

# %%
from scipy.stats import spearmanr

# Assuming you want to calculate the correlation for variables 'Variable1' and 'Variable2'
variable1 = selected_data['Time-test: Количество ошибок, серия 2 (Часть 2) ']
variable2 = selected_data['WMem: Количество объектов, серия 1']

# Calculate the Spearman correlation and p-value for the selected pair of variables
correlation, p_value = spearmanr(variable1, variable2)

# Print the result
print(f"Spearman Correlation: {correlation}")
print(f"P-Value: {p_value}")
# Out:
# Spearman Correlation: 0.31678987979966194
# P-Value: 0.026572082572253804
